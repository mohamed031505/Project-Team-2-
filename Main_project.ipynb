# %%
# Dependencies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as plt 
import requests
import csv

#from census import Census

# %%
# Pulling Data from Main CSV file

#main_csv=pd.read_csv("Resources/1.08_Crash_Data_Report__detail_.csv")

main_crash_df = pd.read_csv("Resources/1.08_Crash_Data_Report__detail_.csv")

main_crash_df.head(100)
                

# x=df[df["Year"]>2015]
# x.max()
# Out:
#              X          Y  OBJECTID  Incidentid                DateTime  Year  \
# 0  -111.926299  33.422027         1     2584487  2012/01/10 05:55:00+00  2012
# 1  -111.909513  33.434986         2     2584442  2012/01/10 14:55:00+00  2012
# 2  -111.961282  33.381066         3     2589844  2012/01/10 15:43:00+00  2012
# 3  -111.892579  33.378452         4     2579417  2012/01/10 16:04:00+00  2012
# 4  -111.894042  33.392986         5     2584480  2012/01/10 18:23:00+00  2012
# ..         ...        ...       ...         ...                     ...   ...
# 95 -111.961521  33.392875        96     2599165  2012/01/13 21:43:00+00  2012
# 96 -111.898719  33.407492        97     2592203  2012/01/13 22:19:00+00  2012
# 97 -111.960925  33.387004        98     2594507  2012/01/13 22:55:00+00  2012
# 98 -111.893719  33.378449        99     2586128  2012/01/13 23:08:00+00  2012
# 99 -111.926281  33.414733       100     2595901  2012/01/13 23:30:00+00  2012
#
# ...

# %%
main_crash_df.dropna(inplace = True)
# new data frame with split value columns
main_crash_split_df = main_crash_df["DateTime"].str.split(" ", n = 1, expand = True)
# making separate first name column from new data frame
main_crash_df["Date"]= main_crash_split_df[0]
# making separate last name column from new data frame
main_crash_df["Time"]= main_crash_split_df[1]
# Dropping old Name columns
main_crash_df.drop(columns =["DateTime"], inplace = True)
# df display
main_crash_df.head()
# Out:
#             X          Y  OBJECTID  Incidentid  Year     StreetName  \
# 1 -111.909513  33.434986         2     2584442  2012  Mcclintock Dr
# 2 -111.961282  33.381066         3     2589844  2012      Priest Dr
# 3 -111.892579  33.378452         4     2579417  2012    Baseline Rd
# 4 -111.894042  33.392986         5     2584480  2012   Southern Ave
# 5 -111.916532  33.407502         6     2592289  2012    Broadway Rd
#
#                      CrossStreet  Distance  \
# 1  State Route 202 Exit 8 A-Ramp  -533.808
# 2                      Darrow Dr   170.016
# 3                       Price Rd   -24.816
# 4                       Price Rd  -617.760
# 5                      Dorsey Ln   352.176
#
#                        JunctionRelation  Totalinjuries  ...  Gender_Drv2  \
# 1  Intersection Related Non Interchange              3  ...       Female
# 2                  Not Junction Related              0  ...       Female
# ...

# %%
# we need  lattiude as longitude
#dataTime
#year 
# may be group by streetName and CrossStreet 
# Total injuries
# injuryseverity
#Unittype_One
#Age_Drv1 <100
# Gender_Drv1 filter on male female unknown
#Violation1_Drv1 - May Be 
#Unitaction_One _ May be 

# under the influence combining Alchol/Drugs into one column and no apparent influence is the second category 

#drive_unit2 
# age_drv2 <100
#Gender male -female or unknown
#Violation1_Drv2 - May Be 
#Unitaction _Two -  May be 
# under the influence combining Alchol/Drugs into one column and no apparent influence is the second category
